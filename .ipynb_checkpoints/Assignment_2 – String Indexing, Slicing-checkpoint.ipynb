# %% [markdown]
# ## Assignment – String Indexing, Slicing

# %%
#Q1. Extract the word "quick".
#Input: "The quick brown fox jumps over the lazy dog"
#Output: "quick"

# %%
str1 = "The quick brown fox jumps over the lazy dog"
str2= str1[4:9]
print(str2)
# Out:
# quick

# %%
#Q2. Reverse the whole sentence.
#Input: "Pack my box with five dozen Apples"
#Output: "selppA nezod evif htiw xob ym kcaP"

# %%
s= "Pack my box with five dozen Apples"
a = s[::-1]
print(a)
# Out:
# selppA nezod evif htiw xob ym kcaP

# %%
#Q3. Extract the phrase "black quartz".
#Input: "Sphinx of black quartz, judge my vow"
#Output: "black quartz"

# %%
e = "Sphinx of black quartz, judge my vow"
q = e[10:22]
print(q)
# Out:
# black quartz

# %%
#Q4. Extract "vexingly quick daft".
#Input: "How vexingly quick daft zebras jump!"
#Output: "vexingly quick daft"

# %%
r ="How vexingly quick daft zebras jump!"
t =r[4:23]
print(t)
# Out:
# vexingly quick daft

# %%
#Q5. Take every second character starting at index 3.
#Input: "Six crazy kings vowed to abolish my quite pitiful jousts"
#Output: "rz ig oe oaoihm ut iiu oss"

# %%
w ="Six crazy kings vowed to abolish my quite pitiful jousts"
o =w[3::2]
print(o)
# Out:
#  rz ig oe oaoihm ut iiu oss

# %%
#Q6. Extract "wizards jump".
#Input: "The five boxing wizards jump quickly"
#Output: "wizards jump"

# %%
ab = "The five boxing wizards jump quickly"
str_1 =ab[16:28]
print(str_1)
# Out:
# wizards jump

# %%
#Q7. Extract "Jackdaws love".
#Input: "Jackdaws love my big sphinx of quartz"
#Output: "Jackdaws love"

# %%
n ="Jackdaws love my big sphinx of quartz"
a=n[0:13]
print(a)
# Out:
# Jackdaws love

# %%
#Q8. Take every 3rd character starting at index 7 up to index 40.
#Input: "Crazy Fredrick bought many very exquisite opal jewels"
#Output: "rrkohmye qse"

# %%
t ="Crazy Fredrick bought many very exquisite opal jewels"
r=t[7:41:3]
print(r)
# Out:
# rrkohmye qse

# %%
#Q9. Reverse the sentence.
#Input: "We promptly judged antique ivory buckles for the next prize"
#Output: "ezirp txen eht rof selkcub yrovi euqitna degduj yltpmorp eW"

# %%
a ="We promptly judged antique ivory buckles for the next prize"
p =a[::-1]
print(p)
# Out:
# ezirp txen eht rof selkcub yrovi euqitna degduj yltpmorp eW

# %%
#Q10. Extract "few discotheques".
#Input: "Amazingly few discotheques provide jukeboxes"
#Output: "few discotheques"

# %%
v ="Amazingly few discotheques provide jukeboxes"
l =v[10:26]
print(l)
# Out:
# few discotheques

# %%
#Q11. Slice using negative indices to extract "enzymed kex".
#Input: "Big Fuji waves pitch enzymed kex liquor"
#Output: "enzymed kex"

# %%
f ="Big Fuji waves pitch enzymed kex liquor"
j =f[-18:-7]
print(j)
# Out:
# enzymed kex

# %%
#Q12. Extract "onyx goblin jumps over".
#Input: "The quick onyx goblin jumps over the lazy dwarf"
#Output: "onyx goblin jumps over"

# %%
w ="The quick onyx goblin jumps over the lazy dwarf"
l=w[10:32]
print(l)
# Out:
# onyx goblin jumps over

# %%
#Q13. Take every −4th character starting from the end.
#Input: "Watch Jeopardy!, Alex Trebek's fun TV quiz game"
#Output: "e q  eTl!aJt"

# %%
v = "Watch Jeopardy!, Alex Trebek's fun TV quiz game"
c =v[::-4]
print(c)
# Out:
# e q  eTl!aJt

# %%
#Q14. Extract "jump; dozy fowl".
#Input: "Bright vixens jump; dozy fowl quack"
#Output: "jump; dozy fowl"

# %%
z ="Bright vixens jump; dozy fowl quack"
x = z[14:29]
print(x)
# Out:
# jump; dozy fowl

# %%
#Q15. Reverse every second character starting from the last character.
#Input: "Cozy lummox gives smart squid who asks for job pen"
#Output: "npbjrfss h iq rm ei omlyo"

# %%
p="Cozy lummox gives smart squid who asks for job pen"
y=p[::-2]
print(y)
# Out:
# npbjrfss h iq rm ei omlyo

# %%
#Q16. Slice the last two words "stylish monks".
#Input: "Jovial debaters feign quick applause for stylish monks"
#Output: "stylish monks"

# %%
i ="Jovial debaters feign quick applause for stylish monks"
n =i[-13:]
print(n)
# Out:
# stylish monks

# %%
#Q17. Extract "galvanized jets".
#Input: "Fix problem quickly with galvanized jets on board"
#Output: "galvanized jets"

# %%
i ="Fix problem quickly with galvanized jets on board"
f=i[-24:-9]
print(f)
# Out:
# galvanized jets

# %%
#Q18. Take the first 12 characters then reverse them.
#Input: "Twelve ziggurats quickly jump from above my deck"
#Output: "uggiz evlewT"

# %%
k ="Twelve ziggurats quickly jump from above my deck"
w =k[:12]
print(w[::-1])
# Out:
# uggiz evlewT

# %%
#Q19. Extract everything after the second-to-last space.
#Input: "Exquisite farm wench gives body jolt to prize stinker"
#Output: "prize stinker"

# %%
f ="Exquisite farm wench gives body jolt to prize stinker"
s = f[-13::]
print(s)
# Out:
# prize stinker

# %%
#Q20. Take characters at positions 7, 9, 11 … 25.
#Input: "Grumpy wizards make toxic brew for the jovial queen"
#Output: "wzrsmk oi "

# %%
i ="Grumpy wizards make toxic brew for the jovial queen"
o =i[7:26:2]
print(o)
# Out:
# wzrsmk oi
