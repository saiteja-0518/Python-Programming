# %% [markdown]
# ## 1. Arithmetic Operators

# %%
# 1 Write a Python program to add two numbers using the + operator.

# %%
a =20
b = 30
add= a+b; # + operation
print("addition of a+b:",add)
# Out:
# Sum of a+b: 50

# %%
# 2 Write a program to subtract b from a.

# %%
x = 20 
y = 10
subtract = x-y; # - operation
print("Subtraction x-y:",subtract)
# Out:
# Subtraction x-y: 10

# %%
# 3 Write a Python program to multiply two numbers.

# %%
m = 10
n = 20
multiply = m*n # * operation 
print("multiplication of m*n:", multiply)
# Out:
# multiplication of m*n: 200

# %%
# 4 Divide 25 by 4 and display both normal division (/) and floor division (//) results.

# %%
q = 25
w = 4
divison = q/w # / operation
floor_division = q//w # // operation
print("divison of q/w:",divison)
print("floor division:",floor_division)
# Out:
# divison of q/w: 6.25
# floor division: 6

# %%
# 5 Write a program to find the remainder when 17 is divided by 3.

# %%
r = 17
s = 3 
remainder = r%s # % operation
print("Remainder of r%s:",remainder)
# Out:
# Remainder of r%s: 2

# %%
# 6 Find the result of 5 ** 3 and explain what it represents.

# %%
e = 5 
d = 3
exponents = e**d # 5 power of 3
print("exponents of e**d:",exponents)
# Out:
# exponents of e**d: 125

# %%
# 7 If a = 10, b = 4, find and print all arithmetic results (+, -, *, /, %, //, **).

# %%
a = 10
b = 4
print("a+b:",a+b) # +
print("a-b:",a-b) # -
print("a*b:",a*b) # *
print("a/b:",a/b) # /
print("a%b:",a%b) # %
print("a//b:",a//b) # //
print("a**b:",a**b) #**
# Out:
# a+b: 14
# a-b: 6
# a*b: 40
# a/b: 2.5
# a%b: 2
# a//b: 2
# a**b: 10000

# %% [markdown]
# ## 2.Assignment Operators

# %%
# 1.Write a Python program to show how += works. Example: x += 3.

# %%
a = 4
a +=7 # a=a+7
print("a+=7:",a)
# Out:
# a+=7: 11

# %%
# 2.Demonstrate the use of -= operator.

# %%
s = 8
s -=3 # s=s-3
print("s-=3:",s)
# Out:
# s-=3: 5

# %%
# 3 Write a program where x = 10, and you apply x*= 5. Print the new value of x.

# %%
x =10
x*=5 # x=x*5
print("x*=5",x)
# Out:
# x*=5 50

# %%
# 4

# %%
m = 20
m /=4 # m=m/4
print("m /=4:",m)
# Out:
# m /=4: 5.0

# %%
# 5 Write a small code showing the working of %= operator.

# %%
q = 30
b =4
q%=b # q= q%b
print("q %= b:",q)
# Out:
# q %= b: 2

# %%
# 6 Show an example using //=, and print before and after values of the variable.

# %%
e = 22
f =5
print("before e//=f",e)
e//=f # e = e//f
print("after e//=f:",e)
# Out:
# before e//=f 22
# after e//=f: 4

# %%
# 7 Write code demonstrating the use of **= for squaring a number.

# %%
w = 5
o = 2
w **=o # w=w**o
print("w**o:",w)
# Out:
# w**o: 25

# %% [markdown]
# ## 3 Comparison (Relational) Operators

# %%
# 1.Write a program to check if two numbers are equal using ==.

# %%
a = 10
b = 10
c=a==b
print("a == b:",c)
# Out:
# a == b: True

# %%
# 2. Write a code to check if a number is not equal to another using !=.

# %%
m =30
n = 20
s = m!=n
print("m != n",s)
# Out:
# m != n True

# %%
# 3 Write a program that takes two numbers and prints whether the first is greater than the second.

# %%
w = 40
x = 10
c = w>x
print("w>x:",c)
# Out:
# w>x: True

# %%
# 4 Write a program using < and > to compare user inputs.

# %%
r = 2
s = 4
d = r <s
m = r>s
print("r<s:",d)
print("r>s:",m)
# Out:
# r<s: True
# r>s: False

# %%
# 5 Demonstrate the use of >= and <= operators with examples.

# %%
e = 3
f = 8
g = e>=f
j = e<=f
print("e>=f:",g)
print("e<=f:",j)
# Out:
# e>=f: False
# e<=f: True

# %%
# 6 Write a program that checks whether a given number is between 10 and 20 (inclusive).

# %%
n = 15
r = n >=10 and n<=20
print("the num is between 10 and 20:",r)
# Out:
# the num is between 10 and 20: True

# %%
# 7 Write a code to compare two strings "apple" and "banana" using < and explain the output.

# %%
str1 = "apple"
str2 ="banana"
compare =str1<str2
print(compare)
# output explanation
# while comparing two strings apple and banana using the <operator it will give True it compare the string by letter by letter
# Out:
# True

# %% [markdown]
# ## 4.Logical Operators

# %%
# 1 Write a program using and operator to check if a number is between 1 and 10.

# %%
t = 4
r = t>=1 and t<=10
print("number is between 1 and 10",r)
# Out:
# number is between 1 and 10 True

# %%
# 2 Use or operator to check if a number is less than 5 or greater than 15.

# %%
u = 20
v = u <5 or u>15
print("number is less than 5 or greater than 15",v)
# Out:
# number is less than 5 or greater than 15 True

# %%
# 3 Demonstrate the use of not operator to reverse a condition.

# %%
x = True
print(not x)
# Out:
# False

# %%
# 4 Predict the output:	
a = 5
print(a > 2 and a < 10)
# output is True
# Out:
# True

# %%
#5 Predict the output:
x = 3
print(x < 2 or x == 3)
# output is True
# Out:
# True

# %%
# 6 Write a small program that takes a user’s age and prints if the person is a teenager (13–19) using and.

# %%
a = 17
o = a>=13 and a<=19
print("user tennager 13 is between 19 :",o)
# Out:
# user tennager 13 is between 19 : True

# %% [markdown]
# ## 5.Identity Operators

# %%
# 1.Write a program using is to check if two variables refer to the same object.

# %%
m = "sai"
n = "sai"
print( "same objects m and n:",m is n)
# Out:
# same objects m and n: False

# %%
# 2.Demonstrate the use of is not operator.

# %%
t = "name"
i = "roll"
print("check the t and i same or not:",t is not i)
# Out:
# check the t and i same or not: True

# %%
# 3. Explain the difference between == and is with an example.

# %%
# ==
# it checks the values are equal or not
# example
a = 20
b = 20
c = a==b # == is check the a value equal to b value
print("checking a==b:",c)

# is
#it checks same object in the memory
a = "sai"
b ="sai"
print("check a is b:",a is b)
# Out:
# checking a==b: True
# check a is b: True

# %%
## 6.Membership Operators

# %%
# 1.Write a program to check if 'a' is present in the string "banana".

# %%
t = "banana"
print("check a is present in banana",'a'in t)
# Out:
# check a is present in banana True

# %%
# 2. Write a program to check if 5 is in the list [1, 2, 3, 4, 5].

# %%
l = [1,2,3,4,5]
print("check 5 is in list",5 in l)
# Out:
# check 5 is in list True

# %%
# 3 Use not in to check if 'cat' is not present in the list ['dog', 'bat', 'rat'].

# %%
li = ['dog','bat','rat']
print("checks cat is in list",'cat' not in li)
# Out:
# checks cat is in list True

# %%
# 4 . Write a small program where the user enters a number, and you check if it is in [10, 20, 30, 40].

# %%
n = 20
li = [10,20,30,40]
print("check 20 is present in the list or not:", n in li)
# Out:
# check 20 is present in the list or not: True

# %% [markdown]
# ## Bitwise Operators

# %%
# 1.Write a program using & (bitwise AND) for two numbers.

# %%
a= 3
b =7
c= a&b
print("Bitwise AND for a and b:",c)
# Out:
# Bitwise and for a and b: 3

# %%
# 2.Demonstrate bitwise | (OR) between 12 and 7.

# %%
e = 12
f = 7
n = e|f
print("Bitwise OR of 12 and 7 :",n)
# Out:
# Bitwise of 12 and 7 : 15

# %%
# 3.Write a code to perform bitwise XOR (^) operation.

# %%
r = 3
t = 6
q = r ^t
print("Bitwise XOR of r and t ",q)
# Out:
# Bitwise XOR of r and t  5

# %%
#4 Write a program using bitwise NOT (~) on a number and explain the result.

# %%
i = 4
print("Bitwise not of i :",~i)
# Out:
# Bitwise not of i : -5

# %%
#5 Demonstrate left shift (<<) operator with x = 5.

# %%
x =5
a = x<<2
print("left shift of x <<2:",a)
# Out:
# left shift of x <<2  20

# %%
#6 Demonstrate right shift (>>) operator with x = 20.

# %%
x =20
s = x>>3
print("right shift os x>>3:",s)
# Out:
# right shift os x>>3: 2

# %%
# 7 Combine multiple bitwise operations in one expression and print result.

# %%
w = 3
z = 8
x = w &z |w ^z
print(x)
# Out:
# 11

# %%
#8 Predict the output of:
x = 10
y = 4
print(x & y, x | y, x ^ y, ~x)
#output 0 14 14 -11
# Out:
# 0 14 14 -11

# %%
## 8.Operator Precedence

# %%
# 1.Predict the output of print(10 + 3 * 2).
print(10 +3 *2)
# output 16
# Out:
# 16

# %%
# 2. Predict the output of print((10 + 3) * 2).
print((10+3)*2)
# Output 26
# Out:
# 26

# %%
# 3.Write a small code showing how parentheses () change the evaluation order.
a = 20+3*2
print("without parantheses",a)
# output 57
b = (20+3)*2
print("with parantheses",b)
# ouptut46
# Out:
# without parantheses 26
# with parantheses 46

# %%
# Predict output:print(2 ** 3 ** 2) (Hint: Right-to-left precedence)
print(2 ** 3 ** 2)
# output 512
# Out:
# 512

# %%
#  Write a program combining arithmetic, comparison, and logical operators and explain the order in which they are executed.

# %%
a =20
b =3
e = (a+b>20) or (a %b ==0)
print(e)
# Out:
# True
