# %%
# Q1. Remove spaces before and after the string, convert to uppercase, and print the length of the final string. Also print the uppercase string.

# %%
str1=" Python Programming "
o =str1.strip()
up=o.upper()
print(up)
print(len(up))
# Out:
# PYTHON PROGRAMMING
# 18

# %%
# Q2. Replace "." with "->", then split into a list and print the final list. Also print the intermediate replaced string.

# %%
s ="hello.world.python"
print(s.replace('.','->'))
print(s.split('.'))
# Out:
# hello->world->python
# ['hello', 'world', 'python']

# %%
# Q3. Replace "a" with "A", then check if the final string ends with "A". Also print the modified string.

# %%
o = "banana"
i =o.replace('a','A')
print(i)
s =i.endswith('A')
print(s)
# Out:
# bAnAnA
# True

# %%
# Q4. Remove "www." and ".com", then print the remaining string. Also print the original and final versions.

# %%
r ="www.username.com"
print(r)
e=r.replace("www.","").replace(".com","")
print(e)
# Out:
# www.username.com
# username

# %%
# Q5. Convert to title case and then check if the final string starts with "Python". Also print the title case string.

# %%
t ="Python is amazing"
print(t.title())
print(t.startswith("Python"))
# Out:
# Python Is Amazing
# True

# %%
#Q6. Remove "@", then check if the final string is alphanumeric. Also print the modified string.

# %%
r = "Data@123"
t =r.replace('@','')
print(t)
e =t.isalnum()
print(e)
# Out:
# Data123
# True

# %%
#Q7. Replace "_" with space, then capitalize only the first word and print the result. Also print the intermediate string after replace.

# %%
h ="hello_world"
q=h.replace('_',' ')
a=q.capitalize()
print(q)
print(a)
# Out:
# hello world
# Hello world

# %%
# Q8. Extract and print only the domain name from the email. Also print the split parts before extraction.

# %%
i ="user@gmail.com"
t=i.split('@')
print(t)
d =t[1].split('.')[0]
print(d)
# Out:
# ['user', 'gmail.com']
# gmail

# %%
#Q9. Strip spaces, convert to uppercase, and check if final result equals "PYTHON". Also print the stripped and uppercase string.

# %%
j=" python "
l =j.strip()
print(l)
u =l.upper()
print(u)
print(u =="PYTHON")
# Out:
# python
# PYTHON
# True

# %%
l ="apple orange banana"
w=l.split()
print(w)
j =','.join(w)
print(j)
# Out:
# ['apple', 'orange', 'banana']
# apple,orange,banana

# %%
# Q11. Convert to lowercase, then capitalize and print the final string. Also print the lowercase version.

# %%
h ="HELLO world"
z=h.lower()
print(z)
print(z.capitalize())
# Out:
# hello world
# Hello world

# %%
#Q12. Convert only the file extension to lowercase and print the result. Also print the filename without modification.

# %%
t="File.PDF"
print(t)
p =t.replace('PDF','pdf')
print(p)
# Out:
# File.PDF
# File.pdf

# %%
# Q13. Replace "ss" with "$$" and print the result. Also print original string.

# %%
j="mississippi"
print(j)
h=j.replace("ss","$$")
print(h)
# Out:
# mississippi
# mi$$i$$ippi

# %%
#Q14. Check if the "coding" part (before .) is alphabetic and print the result. Also print the split parts.

# %%
n ="coding.123"
u =n.split('.')
print(u)
print(u[0].isalpha())
# Out:
# ['coding', '123']
# True

# %%
# Q15. Find index of "brown", check if string ends with "fox", and print both. Also print the sentence.

# %%
y="The quick brown fox"
print(y)
print(y.find("brown"))
print(y.endswith("fox"))
# Out:
# The quick brown fox
# 10
# True

# %%
#Q16. Replace underscores with spaces, convert to title case, and print the final string. Also print the intermediate replaced string.

# %%
t ="hello_world_python"
o=t.replace('_',' ')
print(o)
print(o.title())
# Out:
# hello world python
# Hello World Python

# %%
#Q17. Replace "5" with "FIVE", check if the result is alphanumeric

# %%
p ="12345"
e=p.replace('5','FIVE')
print(e)
print(e.isalnum())
# Out:
# 1234FIVE
# True

# %%
# Q18. Extract and print only the filename without extension. Also print the split parts.

# %%
i = "report.pdf"
e=i.split('.')
print(e)
print(e[0])
# Out:
# ['report', 'pdf']
# report

# %%
#QA19. Check if part before "123" is uppercase and part after is digits, then print both. Also print the split parts.

# %%
o = "PYTHON123"
p=o[:6]
q=o[6:]
print(p,q)
print(p.isupper())
print(q.isdigit())
# Out:
# PYTHON 123
# True
# True

# %%
#Q20. Replace spaces with "_", then check if final result is alphanumeric and print the answer. Also print the modified string.

# %%
o ="Batch 452"
g=o.replace(" ","_")
print(g)
print(g.isalnum())
# Out:
# Batch_452
# False
