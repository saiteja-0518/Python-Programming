# %% [markdown]
# # Today's Agenda
# - Dictionary
# > ### What is Dictionary?
# > ### Different ways of creating Dictionary?
# > ### How to call Dictionary elements?
# > ### How to apply different Dictionary operations?
# > ### What are the built-in functions availble in Dictionary!
# > ### How it is different from the set?

# %% [markdown]
# **A Python dictionary is a data structure that stores key/value pairs. Each element of a Python dictionary is a key/value pair. The keys are like an index operator. In a list, the indexes are integers. In a dictionary, the key must be a hashable object. A dictionary cannot contain duplicate keys. Each key maps to one value. A key and its corresponding value form an item (or entry) stored in a dictionary. The data structure is a called a “dictionary” because it resembles a word dictionary, where the words are the keys and the words’ definitions are the values. A dictionary is also known as a map, which maps each key to a value. It enables fast retrieval, deletion, and updating of the value by using the key.**

# %% [markdown]
# - Dictionaries are a collection in items which consists of key-value pairs
# - Dictionaries are ordered, indexable and mutable
# - Dictionaries are defined using `{}`
# - Dictionaries don't allow duplicate keys

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. Creating a Dictionary
# - You can create a dictionary by enclosing the items inside a pair of curly braces ({}). Each item consists of a key, followed by a colon, followed by a value. The items are separated by commas.

# %% [markdown]
# **You can create an empty dictionary by using the following syntax:**

# %%
# Dictionary with student name and roll no
students = {'1':'sai',2:'teja','3':'g'}
print(students)
print(type(students))
print(len(students))
# dictionary object: students
# Out:
# {'1': 'sai', 2: 'teja', '3': 'g'}
# <class 'dict'>
# 3

# %%
# Empty Dictionary
batch_541 = {}
print(type(batch_541))
# Out:
# <class 'dict'>

# %% [markdown]
# **Note:Python uses curly braces for sets and dictionaries. The syntax {} denotes an empty dictionary.To create an empty set, use set()**

# %% [markdown]
# # 2. Adding, Modifying, and Retrieving Values

# %%
# adding
students['4'] = 'aman'
print(students)
# Out:
# {'1': 'sai', 2: 'teja', '3': 'g', '4': 'aman'}

# %%
# Modifying
students['4'] = 'harsha'
print(students)
# Out:
# {'1': 'sai', 2: 'teja', '3': 'g', '4': 'harsha'}

# %%
# retrieving
students['3']
# Out:
# 'g'

# %%
students['2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 students['2']
#
# KeyError: '2'

# %% [markdown]
# ### get()
# - To prevent a KeyError exception, we can use the get() function on a dictionary. Then, if a value is not found for a given key, it returns nothing (and otherwise returns the value associated with that key).

# %%
students.get('1')
# Out:
# 'sai'

# %%
students.get('2')

# %% [markdown]
# # 3. Getting all
# ### keys()
# ### values()
# ### items()

# %%
students.keys()
# Out:
# dict_keys(['1', 2, '3', '4'])

# %%
students.values()
# Out:
# dict_values(['sai', 'teja', 'g', 'harsha'])

# %%
students.items()
# Out:
# dict_items([('1', 'sai'), (2, 'teja'), ('3', 'g'), ('4', 'harsha')])

# %% [markdown]
# # 4. Common operations
# - in
# - not in
# - ==
# - !=

# %%
# length of dictionary
len(students)
# Out:
# 3

# %%
# We cann not check membership of a value
'Pravesh' in students
# Out:
# False

# %%
# Can check membership of a key
'123' in students
# Out:
# True

# %%
print(students)
students['126'] = 'Vina'
print(students)
# Out:
# {'123': 'Pravesh', '124': 'Vina', '125': 'neelima'}
# {'123': 'Pravesh', '124': 'Vina', '125': 'neelima', '126': 'Vina'}

# %%
students['124'] == students['126']
# Out:
# True

# %%
dict1 = {'age':21, 'name':'Sam'}
dict2 = {'name':'Sam','age':21}
print(dict1 == dict2)
print(dict1 != dict2)
# Out:
# True
# False

# %% [markdown]
# **You cannot use the comparison operators (>, >=, <=, and <) to compare dictionaries because the items are not ordered.**

# %% [markdown]
# # 5.Removing values from a dictionary

# %% [markdown]
# ### pop()
# - remove the key-value pair

# %%
print(students)
students.pop('126') ----'Vina'
print(students)
# Out:
# {'123': 'Pravesh', '124': 'Vina', '125': 'neelima', '126': 'Vina'}
# {'123': 'Pravesh', '124': 'Vina', '125': 'neelima'}

# %% [markdown]
# ### popitem()
# - to remove the last key-value pair

# %%
print(students)
print(students.popitem())
print(students)
# Out:
# {'123': 'Pravesh', '124': 'Vina'}
# ('124', 'Vina')
# {'123': 'Pravesh'}

# %% [markdown]
# ### del
# - using `del` to remove ('Blood group','A-')

# %%
print(students)
del students['123']
print(students)
# Out:
# {'123': 'Pravesh'}
# {}

# %% [markdown]
# # 6.Some dictionary methods

# %% [markdown]
# ### fromkeys()

# %%
keys = ['a','b']
value = 10

dict.fromkeys(keys, value)
# Out:
# {'a': 10, 'b': 10}

# %%
dicts = {}
dicts = dicts.fromkeys(keys, value)
dicts
# Out:
# {'a': 10, 'b': 10}

# %%
keys = ['c','d']
value = 20

dict2 = dict.fromkeys(keys, value)
dict2
# Out:
# {'c': 20, 'd': 20}

# %% [markdown]
# ### unpacking

# %%
{**dict2, **dicts}
# Out:
# {'c': 20, 'd': 20, 'a': 10, 'b': 10}

# %%
dict3 = {**dict2, **dicts}
print(dict3)
# Out:
# {'c': 20, 'd': 20, 'a': 10, 'b': 10}

# %%
dict3.items()
# Out:
# dict_items([('c', 20), ('d', 20), ('a', 10), ('b', 10)])

# %%
for key,value in dict3.items():
    print(key,value)
# Out:
# c 20
# d 20
# a 10
# b 10

# %%
for key,value in dict3.items():
    print(key)
# Out:
# c
# d
# a
# b

# %%
for key,value in dict3.items():
    print(value)
# Out:
# 20
# 20
# 10
# 10

# %% [markdown]
# ### Dictionary methods

# %%
d ={"name": "sai","age":"22","course":"python"}
d
# Out:
# {'name': 'sai', 'age': '22', 'course': 'python'}

# %%
# Keys
d.keys()
# Out:
# dict_keys(['namea', 'age', 'course'])

# %%
d.values()
# Out:
# dict_values(['sai', '22', 'python'])

# %%
d.items()
# Out:
# dict_items([('namea', 'sai'), ('age', '22'), ('course', 'python')])

# %%
d.get("age")
# Out:
# '22'

# %%
d["name"]
# Out:
# 'sai'

# %%
d.pop("age")
# Out:
# '22'

# %%
d
# Out:
# {'name': 'sai'}

# %%
d.popitem()
# Out:
# ('course', 'python')

# %%
d.clear()

# %%
d
# Out:
# {}

# %%
del d

# %%
l =['sai','teja','g']
l
# Out:
# ['sai', 'teja', 'g']

# %%
dict.fromkeys(l,4)
# Out:
# {'sai': 4, 'teja': 4, 'g': 4}

# %%
s ="aeiou"
d1=dict.fromkeys(s,[1,2,3,4])
d1
# Out:
# {'a': [1, 2, 3, 4],
#  'e': [1, 2, 3, 4],
#  'i': [1, 2, 3, 4],
#  'o': [1, 2, 3, 4],
#  'u': [1, 2, 3, 4]}

# %%
d2={}
d2=dict.copy(d1)

# %%
d2`
# Out:
# {'a': [1, 2, 3, 4],
#  'e': [1, 2, 3, 4],
#  'i': [1, 2, 3, 4],
#  'o': [1, 2, 3, 4],
#  'u': [1, 2, 3, 4]}

# %%
d2['a']
# Out:
# [1, 2, 3, 4]

# %%
d2["i"][3]
# Out:
# 4

# %%
d3 =dict.copy(d2)
d3
# Out:
# {'a': [1, 2, 3, 4],
#  'e': [1, 2, 3, 4],
#  'i': [1, 2, 3, 4],
#  'o': [1, 2, 3, 4],
#  'u': [1, 2, 3, 4]}

# %%
d3["o"][3]=9
d3
# Out:
# {'a': [1, 2, 3, 9],
#  'e': [1, 2, 3, 9],
#  'i': [1, 2, 3, 9],
#  'o': [1, 2, 3, 9],
#  'u': [1, 2, 3, 9]}

# %%
# Nested dictonary
d={
    "s1":{"name":"sai","age":22,"city":"hyd"},
    "s2":{"name":"teja","age":23,"city":"kkd"},
    "s3":{"name":"harsha","age":21,"city":"kbhp"}
}

d
# Out:
# {'s1': {'name': 'sai', 'age': 22, 'city': 'hyd'},
#  's2': {'name': 'teja', 'age': 23, 'city': 'kkd'},
#  's3': {'name': 'harsha', 'age': 21, 'city': 'kbhp'}}

# %%
d['s3']["city"]
# Out:
# 'kbhp'

# %%
d["s2"]["age"]
# Out:
# 23
