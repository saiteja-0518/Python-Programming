# %% [markdown]
# # Strings
#
# ## Today's Agenda
# > ### What is Strings?
# > ### How to use Strings?
# > ### What are the different ways to create a strings?
# > ### How to concate multiple strings?
# > ### What are the methods availble in strings
#     - len()
#     - count()
#     - upper()
#     - lower()
#     - capitalize()
#     - title()
#     - find()
#     - replace()
#     - split()
#     - join()
#     - strip()
#     - isdigit()
#     - islapha()

# %% [markdown]
# ## What is String?
#
#
# - A string is a sequence of characters.
# - Computers do not deal with characters, they deal with numbers (binary). Even though you may see characters on    your screen, internally it is stored and manipulated as a combination of 0's and 1's.
# - This conversion of character to a number is called encoding, and the reverse process is decoding. ASCII and Unicode are some of the popular encoding used.
#
# ## Strings are Arrays
# Like many other popular programming languages, strings in Python are arrays of bytes representing unicode characters. However, Python does not have a character data type, a single character is simply a string with a length of 1. Square brackets can be used to access elements of the string.

# %%
# single quotes
'sai teja'
# Out:
# 'sai teja'

# %%
# double quotes
"Gollapalli Sai Teja "
# Out:
# 'Gollapalli Sai Teja '

# %%
" sai's notes"
# Out:
# " sai's notes"

# %%
# triple quotes
'''pyhton is a programming language'''
# Out:
# 'pyhton is a programming language'

# %% [markdown]
# ### Ways to create strings

# %%
# create a string with variables as name
name ='sai'
print(name)
print("="*20)

batch ="541"
print(batch)
print("-"* 20)

course ="python with data science"
print(course)
print("_"*20)
# Out:
# sai
# ====================
# 541
# --------------------
# python with data science
# ____________________

# %% [markdown]
# **NOTE: String, List, Array indexing in Python always begins from 0**
#
# ## String Slicing / String Indexing
#
# You can return a range of characters by using the slice syntax. Specify the start index and the end index, separated by a colon, to return a part of the string.
#
# We will learn advanced slicing when we study lists. Most of the indexing and slicing operations will be similar. Remember, python lists are different than arrays.

# %%
text = 'Python program'
#print(text[7])
text[7]

# print "p"
# Out:
# p
# 'p'

# %%
# fetch "m"
print(text[13])
# what if you have a bigger string
# negative index
print(text[-1])
# Out:
# m
# m

# %%
#printing Pyt
# String concatenation
text[0]+text[1]+text[2]
# Out:
# 'Pyt'

# %%
print(text[0]+text[1]+text[2])
# Out:
# Pyt

# %%
text[0],text[1],text[2]
# Out:
# ('P', 'y', 't')

# %%
print(text[0],text[1],text[2])
# Out:
# P y t

# %%
#print P-y-t
print(text[0],text[1],text[2],sep= '-')
# Out:
# P-y-t

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Indexing position of the each char in a string
#
# - slicing is piece of the value of a string
#
# - denoted by `[ ] `
#
# - We can access individual characters using indexing and a range of characters using slicing.
#
# - Index starts from `0.`
#
# - Trying to access a character out of index range will raise an IndexError.
#
# - The index must be an integer. We can't use float or other types, this will result into TypeError.
#
# - Python allows negative indexing for its sequences.

# %% [markdown]
# The syntax for slicing is `var[start:stop:step]`
# - start: the beginning index of the group of elements we want to access
# - stop: the ending index of the group of elements we want to access
# - step: how many elements to skip, when accessing a group of elements

# %%
#Slice python from Python Program
'Python program'[0:6]
# Out:
# 'Python'

# %%
var = 'Python Program'
var [0:6]
# Out:
# 'Python'

# %%
var [0:6:1]
# Out:
# 'Python'

# %%
var [0:6:2]
# Out:
# 'Pto'

# %% [markdown]
# #### string reversing

# %%
var = "Python program"
var
# Out:
# 'Python program'

# %%
var[ : :]
# Out:
# 'Python Program'

# %%
var[ : :1]
# Out:
# 'Python program'

# %%
var[ : :2]
# Out:
# 'Pto rga'

# %%
# Reverse String

# %%
var[ : :-1]
# Out:
# 'margorp nohtyP'

# %%
# get the sub-string 'marg' by using negative indexing
var[:-5:-1]
# Out:
# 'marg'

# %% [markdown]
# #### Some matematical operations can be performed on strings

# %%
# If + operator is used between two strings, the two strings get added end-to-end
# or they are appended to each other

'Innomatics ' + 'Labs'
# Out:
# 'Innomatics Labs'

# %%
'Innomatics'+' ' +'Labs'
# Out:
# 'Innomatics Labs'

# %%
# the * operator can be used with strings along with an inteeger. The string
# gets appended n number of times to itself, end-to-end
'=' * 5
# Out:
# '====='

# %% [markdown]
# #### to check for the string membership
#
# To check if a sub string is a part of a main string, we'll be using the `in` keyword

# %%
var = 'Innomatics'

# %%
# Check if matics belongs to 'Innomatics'
'matics' in var
# Out:
# False

# %%
'matics' in 'Innomatics'
# Out:
# True

# %% [markdown]
# # Methods or Built-in Function
#
# # len()
# -  to know the number of characters in a string
#
# # upper()
# - to make all the letters in the string capitals
#
# # lower()
# - to make all the letters in a string to lower case
#
# # capitalize()
# - to make the starting letter in the entire string capital

# %%
labs = 'Innomatics'

# %%
name = 'sai'
len(name)
# Out:
# 3

# %%
# Length of string
len(labs)
# Out:
# 10

# %%
sent = " Innomatics labs has 541 batches"
len(sent)
# Out:
# 30

# %%
# Uppercase of String
upp_labs = labs.upper()

# %%
data = " teja"
data.upper()
# Out:
# ' TEJA'

# %%
upp_labs
# Out:
# 'INNOMATICS'

# %%
# Lowercase of string
low_labs = upp_labs.lower()
low_labs
# Out:
# 'innomatics'

# %%
file ="DATA"
file.lower()
# Out:
# 'data'

# %%
# Capitalize
var = "innomatics labs"
cap_var = var.capitalize()

# %%
cap_var
# Out:
# 'Innomatics labs'

# %%
var = "labs"
var.capitalize()
# Out:
# 'Labs'

# %% [markdown]
# # title()
# - if we want to make the starting letter of every word in a string to be in caps

# %%
var1 = "innomatics research labs"

# %%
var1.title()
# Out:
# 'Innomatics Research Labs'

# %% [markdown]
# #### Note: In python, when we're trying to transform strings, the change obsrved is only valid until that cell and isn't made permanent. If we want the change to be made permanent , reassign the value back into the variable

# %% [markdown]
# # count()
# -  to count the number of occurences of a sub-string in the main string

# %%
var = 'innomatic labs'
var
# Out:
# 'innomatic labs'

# %%
var.count('n')
# Out:
# 2

# %%
var.count('labs ')
# Out:
# 0

# %%
var.count('labs')
# Out:
# 1

# %%
var[-2:]
# Out:
# 'bs'

# %%
var.count(var[-4:])
# Out:
# 1

# %%
name = "sai teja"
name.count('a')
# Out:
# 2

# %% [markdown]
# # endswith()
# - to check whether a string is ending in the given sub-string

# %%
var
# Out:
# 'innomatic labs'

# %%
var.endswith('labs')
# Out:
# True

# %%
data = "data science"
data.endswith('science')
# Out:
# True

# %% [markdown]
# # startswith()
# - to check whether a string starts with a given sequence

# %%
var.startswith('in')
# Out:
# True

# %%
var.startswith('In')
# Out:
# False

# %%
name = "sai teja"
name.startswith("s")
# Out:
# False

# %% [markdown]
# # find()
# - find() returns the index position of the starting character of the sub-string

# %%
# Index for sub string that does not exist
var
# Out:
# 'innomatic labs'

# %%
var.find('i')
# Out:
# 0

# %%
var.find('inn')
# Out:
# 0

# %%
var.find('s')
# Out:
# 13

# %%
var.find(" ")
# Out:
# 9

# %%
var.find("nno")
# Out:
# 1

# %%
var.find("no")
# Out:
# 2

# %%
var.find('k')
# Out:
# -1

# %%
name = "raja kumar"
name.find('a')
# Out:
# 1

# %%
# find index number of 2nd n
file = 'indian thing'
idx = file.find('n')
idx_2 = file.find('n', idx +1)
idx_2
idx_3 = file.find('n', idx_2 +2)
idx_3
# Out:
# 10

# %%
# find index number of 2nd n
file = 'bannana'
idx = file.find('n',2)
idx
# Out:
# 2

# %%
var = 'bannana'
print('string is:', var)

idx_n = var.find('n')
print("first of n index is:",idx_n)

idx_2n = var.find('n', idx +2)
print("second of n index is:",idx_2n)
# Out:
# string is: bannana
# first of n index is: 2
# second of n index is: 5

# %%
count('n',var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 count('n',var)
#
# NameError: name 'count' is not defined

# %% [markdown]
# # index()
# - the index() method works similar to the find() method

# %%
var = "innomatics"
var.index('inn')
# Out:
# 0

# %%
var.index('KK')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 var.index('KK')
#
# ValueError: substring not found

# %%
a = "name"
a.index('a')
# Out:
# 1

# %% [markdown]
# # isdigit()
# -  to check if the string contains only numerics
#
# var = "digit_12"

# %%
var.isdigit()
# Out:
# False

# %%
var1 = '1234a'

# %%
var1.isdigit()
# Out:
# False

# %%
value = '9768'
value.isdigit()
# Out:
# True

# %% [markdown]
# var2 = '1234a'
# var2.isdigit()

# %% [markdown]
# # replace()
# - if we want to replace part of a string with a replacement

# %%
var = 'Innomatics'

# %%
var.replace('a', '@')
# Out:
# 'Innom@tics'

# %%
name ="sai teja"
name.replace('a','@')
# Out:
# 's@i tej@'

# %% [markdown]
# # strip()
# - to remove any leading and trailing white spaces and new line characters

# %%
# space
num = ' 1234 '
print(num)

num1 = num.strip()
print(num1)
# Out:
#  1234
# 1234

# %%
num_2 = '@1234@'

# %%
num_2.strip('@')
# Out:
# '1234'

# %%
num_3 = '$1234'

# %%
num_3.strip('$')
# Out:
# '1234'

# %%
num_4 = '$1234 '
num_4
# Out:
# '$1234 '

# %%
num_4 = num_4.strip('$')
num_4
# Out:
# '1234 '

# %%
num_4 = num_4.strip()
num_4
# Out:
# '1234'

# %%
value =" 9768 "
value.strip()
# Out:
# '9768'

# %% [markdown]
# # split()
# - splitting a string into sub-strings based on default delimter(space)

# %%
var = "Innomarics Research Labs"

# %%
var.split()
# Out:
# ['Innomarics', 'Research', 'Labs']

# %%
var.split(' ')
# Out:
# ['Innomarics', 'Research', 'Labs']

# %%
var.split('e')
# Out:
# ['Innomarics R', 's', 'arch Labs']

# %%
var.split(',')
# Out:
# ['Innomarics Research Labs']

# %%
name = "g sai teja"
name.split()
# Out:
# ['g', 'sai', 'teja']

# %% [markdown]
# # format()
# - The format() method is used to make parts of a string dynamic

# %%
print('red ' + 'apple')
# Out:
# red apple

# %%
print("I like Apple")
# Out:
# I like Apple

# %%
# passing the values to the placeholders using the default order
print("I like {}".format('apple'))
# Out:
# I like apple

# %%
# passing the values to the placeholders using the default order
print("I like {} {} mostly.".format('red','apple'))
# Out:
# I like red apple mostly.

# %%
print("I like {} {} mostly. ".format('apple','red'))
# Out:
# I like apple red mostly.

# %%
# passing the values to the placeholders using the positional order
print("I like {1} {0} mostly. ".format('apple','red'))
# Out:
# I like red apple mostly.

# %%
# passing the values to the placeholders using the keyword order
print("I like {color} {fruit} mostly. ".format(color = 'red',fruit = 'apple'))
# Out:
# I like red apple mostly.

# %%
print("my name is {}".format('sai'))
# Out:
# my name is sai

# %%
print(" i am {} from {}".format('sai','AP'))
# Out:
#  i am sai from AP

# %%
print("i am {0} {1}".format('sai','teja'))
# Out:
# i am sai teja

# %%
print("hey good {name} everyone{data}".format(name="morning", data ="what's going on"))
# Out:
# hey good morning everyonewhat's going on

# %% [markdown]
# ## F-string Literals

# %%
color ='red'
fruits ='apple'
print(f"i like {color} {fruits}")
# Out:
# i like red apple

# %% [markdown]
# # User input / Dynamical entry
# > ### input()

# %%
# Input as a Number
num = int(input())
# Out:
# 5

# %%
num
# Out:
# 5

# %%
# Input as a String
name = input("Enter your Name:")
name = name.capitalize()
name
# Out:
# Enter your Name:AMAN
# 'Aman'

# %%
age =int(input("enter your age"))
print(age)
# Out:
# enter your age 4
# 4

# %%
name =input()
# Out:
#  fsafs

# %%
# lower case convert in to Capitalcase
name = input("enter a name")
a =name.capitalize()
print(a)
# Out:
# enter a name 34
# 34

# %%
name
# Out:
# 'aman'

# %% [markdown]
# # Type-casting
# - Type casting is the process of changing a compatible data-type to the other.
# - Like, every datatype can be converted to a string but the reverse is not true.
# - Type casting is achieved by passing the datatype to be converted as an argument to the constructer of the data type we want it to be converted to
